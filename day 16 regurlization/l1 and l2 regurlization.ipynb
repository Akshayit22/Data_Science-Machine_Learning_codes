# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('Melbourne_housing_FULL.csv')
print(dataset.info())
dataset.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
dataset.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
# let's use limited columns which makes more sense for serving our purpose
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount', 
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']
dataset = dataset[cols_to_use]
print(dataset.shape)
dataset.head()
# Out:
# (34857, 15)
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h     SS  Jellis  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 2  Abbotsford      2    h      S  Biggin  Northern Metropolitan
# 3  Abbotsford      3    u     VB  Rounds  Northern Metropolitan
# 4  Abbotsford      3    h     SP  Biggin  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 0         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 2         4019.0       2.5  Yarra City Council       2.0       1.0  0.0
# 3         4019.0       2.5  Yarra City Council       3.0       2.0  1.0
# 4         4019.0       2.5  Yarra City Council       3.0       2.0  0.0
#
#    Landsize  BuildingArea      Price
# 0     126.0           NaN        NaN
# 1     202.0           NaN  1480000.0
# ...

# %%
dataset.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
cols_to_fill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']
dataset[cols_to_fill_zero] = dataset[cols_to_fill_zero].fillna(0)

dataset['Landsize'] = dataset['Landsize'].fillna(dataset.Landsize.mean())
dataset['BuildingArea'] = dataset['BuildingArea'].fillna(dataset.BuildingArea.mean())

dataset.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          3
# Propertycount       0
# Distance            0
# CouncilArea         3
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price            7610
# dtype: int64

# %%
new = dataset[dataset.Price.isna()]
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7610 entries, 0 to 34850
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         7610 non-null   object
#  1   Address        7610 non-null   object
#  2   Rooms          7610 non-null   int64
#  3   Type           7610 non-null   object
#  4   Price          0 non-null      float64
#  5   Method         7610 non-null   object
#  6   SellerG        7610 non-null   object
#  7   Date           7610 non-null   object
#  8   Distance       7610 non-null   float64
#  9   Postcode       7610 non-null   float64
#  10  Bedroom2       5834 non-null   float64
#  11  Bathroom       5831 non-null   float64
#  12  Car            5706 non-null   float64
#  13  Landsize       5065 non-null   float64
#  14  BuildingArea   3086 non-null   float64
#  15  YearBuilt      3467 non-null   float64
#  16  CouncilArea    7610 non-null   object
# ...

# %%
cols_to_fill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']
new[cols_to_fill_zero] = new[cols_to_fill_zero].fillna(0)

new['Landsize'] = new['Landsize'].fillna(new.Landsize.mean())
new['BuildingArea'] = new['BuildingArea'].fillna(new.BuildingArea.mean())

new.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt        4143
# CouncilArea         0
# Lattitude        1722
# Longtitude       1722
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
new = new[cols_to_use]

# %%
n_inp = new.drop('Price', axis=1)
n_tar = new['Price']

n_inp.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# dtype: int64

# %%
n_inp = pd.get_dummies(n_inp, drop_first=True)
print(n_inp.info())
n_inp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7610 entries, 0 to 34850
# Columns: 625 entries, Rooms to CouncilArea_Yarra Ranges Shire Council
# dtypes: float64(7), int64(1), uint8(617)
# memory usage: 5.0 MB
# None
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      2         4019.0       2.5       2.0       1.0  1.0     126.0
# 3      3         4019.0       2.5       3.0       2.0  1.0       0.0
# 7      4         4019.0       2.5       3.0       2.0  2.0     400.0
# 8      2         4019.0       2.5       4.0       1.0  2.0     201.0
# 9      2         4019.0       2.5       3.0       2.0  1.0     202.0
#
#    BuildingArea  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# 0    172.071973                  0                    0  ...
# 3    172.071973                  0                    0  ...
# 7    220.000000                  0                    0  ...
# 8    172.071973                  0                    0  ...
# ...

# %%
dataset.dropna(inplace=True)
dataset.shape
# Out:
# (27244, 15)

# %%
dataset = pd.get_dummies(dataset, drop_first=True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Columns: 34884 entries, Rooms to Regionname_Western Victoria
# dtypes: float64(12), int64(1), uint8(34871)
# memory usage: 1.1 GB

# %%
x = dataset.drop('Price', axis=1)
y = dataset['Price']

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(train_x, train_y)

# %%
print(reg.score(test_x, test_y))
print(reg.score(train_x, train_y))
# Out:
# 0.13853683161537644
# 0.6827792395792723

# %% [markdown]
# Here training score is 68% but test score is 13.85% which is very low
#
# Normal Regression is clearly overfitting the data, let's try other models
#
# ### Using Lasso (L1 Regularized) Regression Model

# %%
from sklearn import linear_model
l1_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
l1_reg.fit(train_x, train_y)

print(l1_reg.score(test_x, test_y))
print(l1_reg.score(train_x, train_y))
# Out:
# 0.6636111369404489
# 0.6766985624766824

# %% [markdown]
# #### Using Ridge (L2 Regularized) Regression Model

# %%
from sklearn.linear_model import Ridge
l2_reg = Ridge(alpha=50, max_iter=100, tol=0.1)
l2_reg.fit(train_x, train_y)

print(l2_reg.score(test_x, test_y))
print(l2_reg.score(train_x, train_y))
# Out:
# 0.6670848945194958
# 0.6622376739684328

# %% [markdown]
# **We see that Lasso and Ridge Regularizations prove to be beneficial when our Simple Linear Regression Model overfits. These results may not be that contrast but significant in most cases.Also that L1 & L2 Regularizations are used in Neural Networks too**

# %%
y_pre = l1_reg.predict(test_x)
new = pd.DataFrame(y_pre)
new['2'] = l2_reg.predict(test_x)

# %%
new.describe()
# Out:
#                   0             2
# count  8.174000e+03  8.174000e+03
# mean   1.051919e+06  1.052720e+06
# std    5.362933e+05  5.128310e+05
# min   -2.384868e+06 -2.217022e+05
# 25%    6.798758e+05  6.919819e+05
# 50%    9.865999e+05  9.944497e+05
# 75%    1.363246e+06  1.355469e+06
# max    4.349892e+06  3.125603e+06

# %%
n_tar = l2_reg.predict(n_inp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12652\1297172396.py in <module>
# ----> 1 n_tar = l2_reg.predict(n_inp)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
#     344
# --> 345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#
# ...
