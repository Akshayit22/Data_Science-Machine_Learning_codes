# %%
import pandas as pd
df = pd.read_csv("carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],color='black')
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],color='black')

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
x = df.drop('Sell Price($)',axis='columns')
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
print(x_train,'\n')
print(x_test,'\n')
print(y_train,'\n')
print(y_test)
# Out:
#     Mileage  Age(yrs)
# 19    52000         5
# 14    82450         7
# 3     22500         2
# 6     52000         5
# 0     69000         6
# 4     46000         4
# 7     72000         6
# 13    58780         4
# 17    69000         5
# 11    79000         7
# 18    87600         8
# 16    28000         2
# 10    83000         7
# 5     59000         5
#
#     Mileage  Age(yrs)
# 12    59000         5
# 9     67000         6
# 1     35000         3
# 2     57000         5
# 8     91000         8
# 15    25400         3
#
# 19    28200
# 14    19400
# 3     40000
# 6     32000
# 0     18000
# 4     31500
# 7     19300
# 13    27500
# 17    19700
# 11    19500
# 18    12800
# 16    35500
# 10    18700
# 5     26750
# Name: Sell Price($), dtype: int64
#
# 12    26000
# 9     22000
# 1     34000
# 2     26100
# 8     12000
# 15    35000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(x_test)
clf.predict(x_test)
# Out:
#     Mileage  Age(yrs)
# 12    59000         5
# 9     67000         6
# 1     35000         3
# 2     57000         5
# 8     91000         8
# 15    25400         3
# array([25846.12461676, 23005.11005381, 34992.00733084, 26712.0880138 ,
#        13859.22733973, 39148.63163667])

# %%
clf.score(x_test, y_test)*100
# Out:
# 93.53820668512358

# %%
x_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)
x_test
# Out:
#     Mileage  Age(yrs)
# 12    59000         5
# 9     67000         6
# 1     35000         3
# 2     57000         5
# 8     91000         8
# 15    25400         3
